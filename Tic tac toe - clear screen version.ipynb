# %%
import random
import os


def DrawBoard(board):
#This section of the code draws the layout of the 3x3 grid

    print('   |   |')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |')




def Playgame():
    #This section of code asks user if they want to play Tic Tac Toe
    UserInput = input ("Would you like to play? ")
    if UserInput == "Yes" or UserInput == "yes":
        print ("Ok, lets get started")  
    else:
        print ("Goodbye")
        #if they do not want to play, the code program will close

def SelectXorO(XX):
    XX = input("Player 1 What would you like to be X or O?")
    if (XX == "X" or XX == "O"):
        print ("Ok Player 1 you will be ", XX)
    else:
        print ("Wrong Selection try again")
        Player1 = ''
    return(XX)
        #assign the user either X or O
    

def WinComboPlayer(board, Player, Win):
    if board[1] ==  Player and board[2] == Player and board[3] == Player: 
        Win = Player
    elif board[4] ==  Player and board[5] == Player and board[6] == Player: 
        Win = Player
    elif board[7] ==  Player and board[8] == Player and board[9] == Player:
        Win = Player
    elif board[7] ==  Player and board[4] == Player and board[1] == Player:
        Win = Player
    elif board[8] ==  Player and board[5] == Player and board[2] == Player:
        Win = Player
    elif board[9] ==  Player and board[6] == Player and board[3] == Player:
        Win = Player
    elif board[1] ==  Player and board[5] == Player and board[9] == Player:
        Win = Player
    elif board[7] ==  Player and board[5] == Player and board[3] == Player:
        Win = Player
    return (Win)

    

#Main
Player1=''
Player2 = '' 
board = [' '] * 10
Player1Turn =0
Player2Turn=0
Win = ' '
print("Tic Tac Toe")


while True:
    Playgame()
    Player1 = SelectXorO(Player1)
    if Player1 == 'X':
            Player2 = 'O'
            break
    elif Player1 == 'O':
            Player2 = 'X'
            break

print("Player 2 = ",Player2, " Player 1 = ", Player1)
while True:
    os.system('cls') 
    os.system('clear')
    Player1Turn = int(input("Player 1 Enter number you want to place your mark 0-8:"))
    print ("Mark is :", board[Player1Turn])
    if (board[Player1Turn] != "X" and board[Player1Turn] != "O"):
        board[Player1Turn] = Player1
    else:
        print ("Space Already taken please try again")
        continue
    DrawBoard(board)
    Win = WinComboPlayer(board, Player1,Win)
    if Win == Player1:
        print ("Player 1 Beat Player 2")
        DrawBoard(board)
        break
    while True:
        os.system('cls') 
        os.system('clear')
        Player2Turn = int(input("Player 2 Enter number you want to place your mark 0-8:"))
        print ("Mark is :", board[Player2Turn])
        if (board[Player2Turn] != "X" and board[Player2Turn] != "O"):
            board[Player2Turn] = Player2
            DrawBoard(board)
            break
        else:
            print ("Space Already taken please try again")
            DrawBoard(board)
            continue
    Win = WinComboPlayer(board, Player2,Win)
    if Win == Player2:
        print ("Player 2 Beat Player 1")
        DrawBoard(board)
        break
